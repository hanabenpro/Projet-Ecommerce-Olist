-- %% [markdown]
-- # [olist]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [olist]    Script Date: 14/11/2025 12:45:42 ******/
CREATE DATABASE [olist]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'olist', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\olist.mdf' , SIZE = 335872KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'olist_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\olist_log.ldf' , SIZE = 335872KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [olist] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [olist].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [olist] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [olist] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [olist] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [olist] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [olist] SET ARITHABORT OFF 
GO
ALTER DATABASE [olist] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [olist] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [olist] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [olist] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [olist] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [olist] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [olist] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [olist] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [olist] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [olist] SET  DISABLE_BROKER 
GO
ALTER DATABASE [olist] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [olist] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [olist] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [olist] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [olist] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [olist] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [olist] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [olist] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [olist] SET  MULTI_USER 
GO
ALTER DATABASE [olist] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [olist] SET DB_CHAINING OFF 
GO
ALTER DATABASE [olist] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [olist] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [olist] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [olist] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [olist] SET QUERY_STORE = ON
GO
ALTER DATABASE [olist] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [mart]

-- %%
USE [olist]
GO

-- %%
/****** Object:  Schema [mart]    Script Date: 14/11/2025 12:45:42 ******/
CREATE SCHEMA [mart]
GO

-- %% [markdown]
-- # [stg]

-- %%
/****** Object:  Schema [stg]    Script Date: 14/11/2025 12:45:42 ******/
CREATE SCHEMA [stg]
GO

-- %% [markdown]
-- # [mart].[dim_customers]

-- %%
/****** Object:  Table [mart].[dim_customers]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [mart].[dim_customers](
	[customer_id] [varchar](50) NOT NULL,
	[customer_unique_id] [varchar](50) NULL,
	[customer_city] [varchar](50) NULL,
	[customer_state] [varchar](50) NULL,
	[customer_zip_code_prefix] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[customer_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [mart].[dim_geolocation]

-- %%
/****** Object:  Table [mart].[dim_geolocation]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [mart].[dim_geolocation](
	[zip_code_prefix] [int] NOT NULL,
	[geolocation_lat] [float] NULL,
	[geolocation_lng] [float] NULL,
	[geolocation_city] [varchar](50) NULL,
	[geolocation_state] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[zip_code_prefix] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [mart].[dim_products]

-- %%
/****** Object:  Table [mart].[dim_products]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [mart].[dim_products](
	[product_id] [varchar](50) NOT NULL,
	[product_category_name] [varchar](100) NULL,
	[product_category_name_english] [varchar](100) NULL,
	[product_weight_g] [float] NULL,
	[product_length_cm] [float] NULL,
	[product_height_cm] [float] NULL,
	[product_width_cm] [float] NULL,
	[product_volume_cm3] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[product_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [mart].[dim_review]

-- %%
/****** Object:  Table [mart].[dim_review]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [mart].[dim_review](
	[review_id] [varchar](50) NOT NULL,
	[order_id] [varchar](50) NULL,
	[review_score] [int] NULL,
	[result_concatenation_coms] [nvarchar](max) NULL,
	[review_creation_date] [datetime] NULL,
	[review_answer_timestamp] [datetime] NULL,
	[review_key] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_dim_review] PRIMARY KEY CLUSTERED 
(
	[review_key] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [mart].[dim_sellers]

-- %%
/****** Object:  Table [mart].[dim_sellers]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [mart].[dim_sellers](
	[seller_id] [varchar](50) NOT NULL,
	[seller_city] [varchar](50) NULL,
	[seller_state] [varchar](50) NULL,
	[seller_zip_code_prefix] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[seller_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [mart].[fact_orders]

-- %%
/****** Object:  Table [mart].[fact_orders]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [mart].[fact_orders](
	[order_id] [varchar](50) NOT NULL,
	[order_item_id] [int] NOT NULL,
	[customer_id] [varchar](50) NULL,
	[seller_id] [varchar](50) NULL,
	[product_id] [varchar](50) NULL,
	[purchase_date] [datetime] NULL,
	[expedition_date] [datetime] NULL,
	[delivery_date] [datetime] NULL,
	[estimated_delivery_date] [datetime] NULL,
	[price] [float] NULL,
	[freight_value] [float] NULL,
	[payment_value] [float] NULL,
	[payment_type] [varchar](50) NULL,
	[review_score] [int] NULL,
	[delivery_delay_days] [int] NULL,
	[delivery_time_days] [int] NULL,
	[is_late_delivery] [bit] NULL,
	[total_revenue] [float] NULL,
	[shipping_limit_date] [datetime] NULL,
	[expedition_delay_days] [int] NULL,
	[total_delivery_days] [int] NULL,
	[review_key] [int] NULL,
 CONSTRAINT [PK_fact_orders] PRIMARY KEY CLUSTERED 
(
	[order_id] ASC,
	[order_item_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_category_clean]

-- %%
/****** Object:  Table [stg].[stg_category_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_category_clean](
	[product_category_name] [nvarchar](50) NOT NULL,
	[product_category_name_english] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_category_clean] PRIMARY KEY CLUSTERED 
(
	[product_category_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_customers_clean]

-- %%
/****** Object:  Table [stg].[stg_customers_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_customers_clean](
	[customer_id] [nvarchar](50) NOT NULL,
	[customer_unique_id] [nvarchar](50) NOT NULL,
	[customer_zip_code_prefix] [int] NOT NULL,
	[customer_city] [nvarchar](50) NOT NULL,
	[customer_state] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_customers_clean] PRIMARY KEY CLUSTERED 
(
	[customer_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_geo_clean]

-- %%
/****** Object:  Table [stg].[stg_geo_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_geo_clean](
	[geolocation_zip_code_prefix] [int] NOT NULL,
	[geolocation_lat] [nvarchar](50) NOT NULL,
	[geolocation_lng] [nvarchar](50) NOT NULL,
	[geolocation_city] [nvarchar](50) NOT NULL,
	[geolocation_state] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_geo_clean] PRIMARY KEY CLUSTERED 
(
	[geolocation_zip_code_prefix] ASC,
	[geolocation_lat] ASC,
	[geolocation_lng] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_order_items_clean]

-- %%
/****** Object:  Table [stg].[stg_order_items_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_order_items_clean](
	[order_id] [nvarchar](50) NOT NULL,
	[order_item_id] [nvarchar](50) NOT NULL,
	[product_id] [nvarchar](50) NOT NULL,
	[seller_id] [nvarchar](50) NOT NULL,
	[shipping_limit_date] [datetime2](7) NULL,
	[price] [float] NULL,
	[freight_value] [float] NULL,
 CONSTRAINT [PK_order_items_clean] PRIMARY KEY CLUSTERED 
(
	[order_id] ASC,
	[order_item_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_orders_clean]

-- %%
/****** Object:  Table [stg].[stg_orders_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_orders_clean](
	[column1] [nvarchar](50) NOT NULL,
	[order_id] [nvarchar](50) NOT NULL,
	[customer_id] [nvarchar](50) NOT NULL,
	[order_status] [nvarchar](50) NOT NULL,
	[order_purchase_timestamp] [datetime2](7) NULL,
	[order_approved_at] [datetime2](7) NULL,
	[order_delivered_carrier_date] [datetime2](7) NULL,
	[order_delivered_customer_date] [datetime2](7) NULL,
	[order_estimated_delivery_date] [datetime2](7) NULL,
	[review_key] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_orders_clean] PRIMARY KEY CLUSTERED 
(
	[review_key] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_payments_clean]

-- %%
/****** Object:  Table [stg].[stg_payments_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_payments_clean](
	[order_id] [nvarchar](50) NOT NULL,
	[payment_sequential] [tinyint] NOT NULL,
	[payment_type] [nvarchar](50) NOT NULL,
	[payment_installments] [nvarchar](50) NOT NULL,
	[payment_value] [float] NULL,
 CONSTRAINT [PK_payments_clean] PRIMARY KEY CLUSTERED 
(
	[order_id] ASC,
	[payment_sequential] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_products_clean]

-- %%
/****** Object:  Table [stg].[stg_products_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_products_clean](
	[product_id] [nvarchar](50) NOT NULL,
	[product_category_name] [nvarchar](50) NOT NULL,
	[product_weight_g] [nvarchar](50) NOT NULL,
	[product_length_cm] [nvarchar](50) NOT NULL,
	[product_height_cm] [nvarchar](50) NOT NULL,
	[product_width_cm] [nvarchar](50) NOT NULL,
	[product_volume_cm3] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_reviews_clean]

-- %%
/****** Object:  Table [stg].[stg_reviews_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_reviews_clean](
	[review_id] [nvarchar](50) NOT NULL,
	[order_id] [nvarchar](50) NOT NULL,
	[review_score] [int] NULL,
	[review_comment_title] [nvarchar](50) NULL,
	[review_comment_message] [nvarchar](250) NULL,
	[review_creation_date] [datetime2](7) NOT NULL,
	[review_answer_timestamp] [datetime2](7) NOT NULL,
	[result_concatenation_coms] [nvarchar](250) NULL,
	[review_key] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_dim_review] PRIMARY KEY CLUSTERED 
(
	[review_key] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [stg].[stg_sellers_clean]

-- %%
/****** Object:  Table [stg].[stg_sellers_clean]    Script Date: 14/11/2025 12:45:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [stg].[stg_sellers_clean](
	[seller_id] [nvarchar](50) NOT NULL,
	[seller_zip_code_prefix] [int] NOT NULL,
	[seller_city] [nvarchar](50) NOT NULL,
	[seller_state] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_sellers_clean] PRIMARY KEY CLUSTERED 
(
	[seller_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_fact_orders_customers]

-- %%
ALTER TABLE [mart].[fact_orders]  WITH CHECK ADD  CONSTRAINT [FK_fact_orders_customers] FOREIGN KEY([customer_id])
REFERENCES [mart].[dim_customers] ([customer_id])
GO
ALTER TABLE [mart].[fact_orders] CHECK CONSTRAINT [FK_fact_orders_customers]
GO

-- %% [markdown]
-- # [FK_fact_orders_dim_review]

-- %%
ALTER TABLE [mart].[fact_orders]  WITH CHECK ADD  CONSTRAINT [FK_fact_orders_dim_review] FOREIGN KEY([review_key])
REFERENCES [mart].[dim_review] ([review_key])
GO
ALTER TABLE [mart].[fact_orders] CHECK CONSTRAINT [FK_fact_orders_dim_review]
GO

-- %% [markdown]
-- # [FK_fact_orders_products]

-- %%
ALTER TABLE [mart].[fact_orders]  WITH CHECK ADD  CONSTRAINT [FK_fact_orders_products] FOREIGN KEY([product_id])
REFERENCES [mart].[dim_products] ([product_id])
GO
ALTER TABLE [mart].[fact_orders] CHECK CONSTRAINT [FK_fact_orders_products]
GO

-- %% [markdown]
-- # [FK_fact_orders_sellers]

-- %%
ALTER TABLE [mart].[fact_orders]  WITH CHECK ADD  CONSTRAINT [FK_fact_orders_sellers] FOREIGN KEY([seller_id])
REFERENCES [mart].[dim_sellers] ([seller_id])
GO
ALTER TABLE [mart].[fact_orders] CHECK CONSTRAINT [FK_fact_orders_sellers]
GO

-- %% [markdown]
-- # [olist]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [olist] SET  READ_WRITE 
GO
